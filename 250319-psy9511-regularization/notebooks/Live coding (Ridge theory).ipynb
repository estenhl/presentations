# %%
import pandas as pd

df = pd.read_csv('~/Downloads/Auto.csv')
df = df[df['horsepower'] != '?']
df['horsepower'] = df['horsepower'].astype(float)

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression()
model.fit(df[['horsepower']], df['mpg'])
# Out:
# LinearRegression()

# %%
print(model.intercept_, model.coef_)
# Out:
# 39.935861021170524 [-0.15784473]

# %%
import matplotlib.pyplot as plt
import numpy as np

df['horsepower'].values[0]

x = np.arange(-0.5 ,0.5, 0.01)
ys = []
errors = []
mean_errors = []

for coef in x:

    yhat = df['horsepower'] * coef + model.intercept_
    mean_error = np.mean((df['mpg'] - yhat) ** 2)
    ys.append(yhat)
    errors.append(true_value - yhat)
    mean_errors.append(mean_error)


plt.plot(x, mean_errors)
plt.show()
