# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression
import numpy as np


df = pd.read_csv('~/Downloads/Auto.csv')
df = df[df['horsepower'] != '?']
df['horsepower'] = df['horsepower'].astype(float)
df['muscle'] = df['horsepower'].apply(lambda x: x > np.mean(df['horsepower'])).astype(int)

model = LogisticRegression()
model.fit(df[['year', 'weight']], df['muscle'])

model.predict(df[['year', 'weight']])
model.predict_proba(df[['year', 'weight']])
# Out:
# array([[1.43065471e-01, 8.56934529e-01],
#        [8.10466320e-02, 9.18953368e-01],
#        [1.73580698e-01, 8.26419302e-01],
#        [1.75038571e-01, 8.24961429e-01],
#        [1.67374007e-01, 8.32625993e-01],
#        [9.79384734e-03, 9.90206153e-01],
#        [9.37719827e-03, 9.90622802e-01],
#        [1.07904857e-02, 9.89209514e-01],
#        [7.39314322e-03, 9.92606857e-01],
#        [4.93449709e-02, 9.50655029e-01],
#        [1.20334063e-01, 8.79665937e-01],
#        [1.04838058e-01, 8.95161942e-01],
#        [6.55092620e-02, 9.34490738e-01],
#        [4.06441066e-01, 5.93558934e-01],
#        [8.84126093e-01, 1.15873907e-01],
#        [6.16695955e-01, 3.83304045e-01],
#        [6.62567941e-01, 3.37432059e-01],
#        [7.86869461e-01, 2.13130539e-01],
#        [9.45277376e-01, 5.47226242e-02],
#        [9.79066684e-01, 2.09333160e-02],
#        [7.34808587e-01, 2.65191413e-01],
#        [8.62506049e-01, 1.37493951e-01],
#        [8.83084321e-01, 1.16915679e-01],
# ...
